# %%
import pandas as pd
import numpy as np

# First, load the dataset (This defines 'df')
df = pd.read_csv('netflix_data.csv')

# Now you can determine the number of rows and columns
print(f"\nDataset Shape: {df.shape}")
# Out:
# Dataset Shape: (750, 10)
